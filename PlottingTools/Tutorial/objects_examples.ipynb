# %% [markdown]
# # Objects examples

# %% [markdown]
# The Objects class aims to provide access to unique observations made by LSST within a certain time range and specified orbital parameters.

# %%
import sys

sys.path.append("../Source")

# %% [markdown]
# ### Object class

# %%
from collection import Objects

# %% [markdown]
# Objects(
#
#     start_time,
#     end_time,
#     filters: Optional[list],
#     **orbital_elements
# ):

# %%
# %%time

#instatiate Objects
example_objs = Objects(
    start_time = "2023-04-09",
    end_time = "2023-04-10",
    filters = "all",
    min_a = 0,
    max_a = 2,
    max_e = 0.8
)
# Out:
# CPU times: user 2.15 ms, sys: 0 ns, total: 2.15 ms
# Wall time: 2.11 ms

# %% [markdown]
# ### Plot objects

# %%
example_objs.heliocentric_view(
    add_planets = True
)

# %%
example_objs.heliocentric_hexplot(
    add_planets = True
)

# %%
example_objs.single_heliocentric_hexplot(
    filters = ["r", "g", "i"],
    add_planets = True
)

# %%
example_objs.heliocentric_histogram(
    add_planets = True
)

# %%
example_objs.single_heliocentric_histogram(
    add_planets = True,
    filters = ["r", "g", "i"]
)

# %%
example_objs.topocentric_view(
)

# %%
example_objs.single_topocentric_plots(
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
example_objs.topocentric_histogram(
)

# %%
example_objs.single_topocentric_histogram(
)

# %%
example_objs.single_topocentric_hexplot(
)
# Out:
# No data for plot to be made

# %%
example_objs.topocentric_hexplot(

)

# %%
example_objs.data
# Out:
#                ssobjectid filter  heliocentricx  heliocentricy  heliocentricz  \
# 0    -9213694311644977123      z      -1.791650       0.425329      -0.176701
# 1    -9205833409374161575      i      -2.136448       0.320772      -0.311040
# 2    -9205833409374161575      z      -1.554038      -1.306646      -0.449877
# 3    -9172009371883974933      r      -1.909520       0.638646      -0.534411
# 4    -9172009371883974933      y      -1.745596       1.094760      -0.366190
# ...                   ...    ...            ...            ...            ...
# 2067  9201762111851651152      i      -1.565437      -0.684437      -0.928141
# 2068  9201762111851651152      r      -0.207601      -1.675058      -1.203351
# 2069  9201762111851651152      z      -1.754133      -0.258742      -0.693394
# 2070  9202772195069854926      r       0.674296       1.637145       0.064430
# 2071  9214821140565181693      z      -1.682272      -0.057673      -0.848521
#
# ...

# %% [markdown]
# ### Orbital relations hexplot

# %% [markdown]
# orbital_relations_hexplot(
#
#          x : Literal["incl", "q", "e", "a"],
#          y : Literal["incl", "q", "e", "a"],
#          title : Optional[str] = None,
#          cache_data: Optional[bool] = False
# ):

# %%
or_hex = example_objs.orbital_relations_hexplot(
    x = "a",
    y = "incl",
    title = "09-12 April 2023"
)

# %% [markdown]
# ### Orbital relations histogram

# %% [markdown]
# orbital_relations_histogram(
#
#          x : Literal["incl", "q", "e", "a"],
#          y : Literal["incl", "q", "e", "a"],
#          title : Optional[str] = None,
#          cache_data: Optional[bool] = False
# ):

# %%
or_hist = example_objs.orbital_relations_histogram(
    x = "q",
    y = "e",
    title = "09-12 April 2023"
)

# %% [markdown]
# ### Orbital relations scatter

# %% [markdown]
# orbital_relations_scatter(
#
#          x : Literal["incl", "q", "e", "a"],
#          y : Literal["incl", "q", "e", "a"],
#          title : Optional[str] = None,
#          cache_data: Optional[bool] = False
# ):

# %%
or_scatter = example_objs.orbital_relations_scatter(
    x = "e",
    y = "q",
    title = "09-12 April Relations between eccentricity and perihelion"
)

# %% [markdown]
# ### All orbital distributions

# %% [markdown]
# all_orbital_distributions(
#
#         filters: Optional[list] = None,
#         plot_type: Literal["box", "violin", "boxen"] = 'BOX',
#         title : Optional[str] = None,
#         cache_data: Optional[bool] = False
#     ):

# %%
example_objs.all_orbital_distributions(
    filters = ["r", "g", "i", "z", "y"],
    plot_type = "violin",
)

# %%
or_hex.fig.suptitle("Inclination versus Semi-Major axis")
# Out:
# Text(0.5, 0.98, 'Inclination versus Semi-Major axis')

# %% [markdown]
# ### Eccentricity distributions

# %% [markdown]
# e_distributions(
#
#         filters: Optional[list] = None,
#         plot_type: Literal[PLOT_TYPES] = 'BOX',
#         title : Optional[str] = None,
#         library: Optional[str] = "seaborn",
#         cache_data: Optional[bool] = False
#     ):

# %%
example_objs.e_distributions(
    filters = ["r", "g", "i", "z", "y"],
    plot_type = "violin"
)

# %% [markdown]
# ### Semi- Major axis distributions

# %% [markdown]
# a_distributions(
#
#         filters: Optional[list] = None,
#         plot_type: Literal['box', 'violin', 'boxen'] = 'BOX',
#         title : Optional[str] = None,
#         library: Optional[str] = "seaborn",
#         cache_data: Optional[bool] = False
#     ):

# %%
example_objs.a_distributions(
    filters = ["r", "g", "i", "z", "y"],
    plot_type = "boxen"
)

# %% [markdown]
# ### Perihelion distributions

# %% [markdown]
# q_distributions(
#
#         filters: Optional[list] = None,
#         plot_type: Literal[PLOT_TYPES] = 'BOX',
#         title : Optional[str] = None,
#         cache_data: Optional[bool] = False
#     ):

# %%
example_objs.q_distributions(
    filters = ["r", "g", "i", "z", "y"],
    plot_type = "box"
)

# %% [markdown]
# ### Inclination distributions

# %% [markdown]
# incl_distributions(
#
#         filters: Optional[list] = None,
#         plot_type: Literal[PLOT_TYPES] = 'BOX',
#         title : Optional[str] = None,
#         library: Optional[str] = "seaborn",
#         cache_data: Optional[bool] = False
#     ):

# %%
example_objs.incl_distributions(
    filters = ["r", "g", "i", "z", "y"],
    plot_type = "boxen"
)

# %% [markdown]
# ### Tisserand relations scatter

# %% [markdown]
# tisserand_relations_scatter(
#
#     y : Literal["incl", "q", "e", "a"],
#     title : Optional[str] = None,
#     cache_data: Optional[bool] = False
# ):

# %%
tiss_scatter = example_objs.tisserand_relations_scatter(
    y = "incl",
    title = "Tisserand scatter relations",
    cache_data = False
)

# %% [markdown]
# ### Tisserand relations hexplot

# %% [markdown]
# tisserand_relations_hexplot(
#
#         y : Literal["incl", "q", "e", "a"],
#         title : Optional[str] = None,
#         cache_data: Optional[bool] = False
#     )

# %%
tiss_hex = example_objs.tisserand_relations_hexplot(
    y = "a",
    title = "Tisserand hexplot relations"
)

# %% [markdown]
# ### Tisserand relations histogram

# %% [markdown]
# tisserand_relations_histogram(
#
#         y : Literal["incl", "q", "e", "a"],
#         title : Optional[str] = None,
#         cache_data: Optional[bool] = False
#     )

# %%
tiss_histogram = example_objs.tisserand_relations_histogram(
    y = "q",
    title = "Tisserand histogram relations"
)
